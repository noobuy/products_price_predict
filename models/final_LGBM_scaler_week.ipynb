# %% [markdown]
# | EDA dataframe      | Description |due|
# | ----------- | ----------- |----------- |
# | grape_df  | 캠벨얼리 가격/거래량  |20190101 ~ 20201104|
# | df      | grape_train + shinemuscat_train       | 20190101 ~ 2020928|
#
#
# **train accuracy / test accuracy 의 차이 비교 overfitting = 20% 이상 (10~20%)**

# %% [markdown]
# https://dacon.io/competitions/official/235801/codeshare/4063?page=1&dtype=recent
#
# [lgbm 튜닝](https://dacon.io/competitions/official/235698/talkboard/404322)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic'

from numpy import array
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import matplotlib as mpl
from IPython.core.display import display, HTML
from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from statsmodels.tsa.seasonal import seasonal_decompose, STL
import urllib.request
import requests
import json
import datetime
import os
from datetime import datetime
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')
# Out:
# /var/folders/lm/z4n_2b8s6rj3_vv57sg789kc0000gn/T/ipykernel_75142/2031877544.py:10: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
# iMAC

raw_path = '/Users/cge/Documents/yeardream/project/kurly/products_price_predict/data/raw/'
processed_path = '/Users/cge/Documents/yeardream/project/kurly/products_price_predict/data/processed/'

# %%
# Macbook
    
# raw_path = '/Users/goeun/Documents/YearDream/ProJect/kurly_project/products_price_predict/data/raw/'
# processed_path = '/Users/goeun/Documents/YearDream/ProJect/kurly_project/products_price_predict/data/processed/'

# %%
grape = pd.read_csv(processed_path+'캠벨얼리_전처리후.csv')
mushroom = pd.read_csv(processed_path+'팽이버섯_전처리후.csv')
tomato = pd.read_csv(processed_path+'토마토_전처리후.csv')
welsh = pd.read_csv(processed_path+'대파_전처리후.csv')
plant = pd.read_csv(processed_path+'깻잎_전처리후.csv')

private = pd.read_csv(raw_path+'private_data.csv')
submission = pd.read_csv(raw_path+'sample_submission.csv')

print(grape.shape)
print(mushroom.shape)
print(private.shape)
print(submission.shape)
# Out:
# (1770, 9)
# (1770, 9)
# (1770, 15)
# (291, 44)
# (228, 22)

# %%
tomato.drop(columns=['요일_0','요일_1', '요일_2', '요일_3', '요일_4', '요일_5', '요일_6'], inplace=True)
welsh.drop(columns=['요일_0','요일_1', '요일_2', '요일_3', '요일_4', '요일_5', '요일_6'], inplace=True)
plant.drop(columns=['요일_0','요일_1', '요일_2', '요일_3', '요일_4', '요일_5', '요일_6'], inplace=True)

# %%
df = pd.merge(grape, mushroom, on=['date', '요일','계절'])
df = pd.merge(df, tomato, on =['date', '계절'] )
df = pd.merge(df, welsh, on = ['date','계절'])
df = pd.merge(df, plant, on = ['date','계절'])

train = df[:1733]
test = df[1733:]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1733 entries, 0 to 1732
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              1733 non-null   object
#  1   요일                1733 non-null   object
#  2   캠벨얼리_거래량(kg)      1733 non-null   float64
#  3   캠벨얼리_가격(원/kg)     1733 non-null   float64
#  4   캠벨얼리_거래량의_1주전_평균  1733 non-null   float64
#  5   캠벨얼리_가격의_1주전_평균   1733 non-null   float64
#  6   캠벨얼리_거래량의_2주전_평균  1733 non-null   float64
#  7   캠벨얼리_가격의_2주전_평균   1733 non-null   float64
#  8   계절                1733 non-null   int64
#  9   팽이버섯_거래량(kg)      1733 non-null   float64
#  10  팽이버섯_가격(원/kg)     1733 non-null   float64
#  11  팽이버섯_거래량의_1주전_평균  1733 non-null   float64
#  12  팽이버섯_가격의_1주전_평균   1733 non-null   float64
#  13  팽이버섯_거래량의_2주전_평균  1733 non-null   float64
#  14  팽이버섯_가격의_2주전_평균   1733 non-null   float64
#  15  토마토_거래량(kg)       1733 non-null   float64
#  16  토마토_가격(원/kg)      1733 non-null   float64
#  17  토마토_거래량의_1주전_평균   1733 non-null   float64
#  18  토마토_가격의_1주전_평균    1733 non-null   float64
#  19  토마토_거래량의_2주전_평균   1733 non-null   float64
#  20  토마토_가격의_2주전_평균    1733 non-null   float64
#  21  대파_거래량(kg)        1733 non-null   float64
#  22  대파_가격(원/kg)       1733 non-null   float64
#  23  대파_거래량의_1주전_평균    1733 non-null   float64
#  24  대파_가격의_1주전_평균     1733 non-null   float64
#  25  대파_거래량의_2주전_평균    1733 non-null   float64
#  26  대파_가격의_2주전_평균     1733 non-null   float64
#  27  깻잎_거래량(kg)        1733 non-null   float64
#  28  깻잎_가격(원/kg)       1733 non-null   float64
#  29  깻잎_거래량의_1주전_평균    1733 non-null   float64
#  30  깻잎_가격의_1주전_평균     1733 non-null   float64
#  31  깻잎_거래량의_2주전_평균    1733 non-null   float64
#  32  깻잎_가격의_2주전_평균     1733 non-null   float64
# dtypes: float64(30), int64(1), object(2)
# memory usage: 460.3+ KB

# %% [markdown]
# # LGBM(LightGBM)

# %% [markdown]
# ## 대파 & 깻잎 & 팽이버섯 & 토마토 & 캠벨얼리

# %%
private2 = private.copy()
private2 = private2[['date','대파_거래량(kg)', '대파_가격(원/kg)', '깻잎_거래량(kg)', '깻잎_가격(원/kg)',
               '팽이버섯_거래량(kg)', '팽이버섯_가격(원/kg)', '토마토_거래량(kg)', '토마토_가격(원/kg)', '캠벨얼리_거래량(kg)', '캠벨얼리_가격(원/kg)',]]

# %%
private2['date'] = private2.date.astype(str).str.replace('-','')
private2['date'] = pd.to_datetime(private2.date, format='%Y%m%d')


t = ['월요일', '화요일', '수요일', '목요일', '금요일', '토요일', '일요일']
private2['요일'] = 0
temp = []
for i in range(len(private2)):
      temp.append(t[int(private2['date'][i].weekday())])
private2['요일'] = temp

private2 = private2[['date', '요일','대파_거래량(kg)', '대파_가격(원/kg)', '깻잎_거래량(kg)', '깻잎_가격(원/kg)',
               '팽이버섯_거래량(kg)', '팽이버섯_가격(원/kg)', '토마토_거래량(kg)', '토마토_가격(원/kg)', '캠벨얼리_거래량(kg)', '캠벨얼리_가격(원/kg)',]]

# %%
class Nong1:
    

  def __init__(self, df, test):
    self.df = df
    self.test = test
    self.df = pd.concat([self.df, self.test], axis=0).reset_index(drop=True)
    self.df = self.df[1:].replace(0, np.NaN)
    self.df = self.df.interpolate().fillna(0)
    self.df.date = pd.to_datetime(self.df.date)
    self.df = pd.concat([self.df, pd.get_dummies(self.df['요일'])], axis=1)
    self.feature = self.df.columns[2:]
    self.df = self.df.reset_index(drop=True)

  def set_feature(self,name):
    self.name = name
    self.name1 = name+ "_가격(원/kg)"
    self.name2 = name+ "_거래량(kg)"
    self.name3 = name+ "_거래량의_1주전_평균"
    self.name4 = name+ '_가격의_1주전_평균'
    self.name5 = name+ '_거래량의_2주전_평균'
    self.name6 = name+ '_가격의_2주전_평균'
    self.name7 = '계절'
    self.feature = [self.name1, self.name2, self.name3, self.name4, self.name5, self.name6, self.name7, '금요일',   '목요일',   '수요일',   '월요일',   '일요일',   '토요일',   '화요일', 'resid']

  def set_target(self,week):
    if week == 1:
      self.df['target'] = self.df[self.name1].shift(-8)
    elif week == 2:
      self.df['target'] = self.df[self.name1].shift(-15)
    elif week == 4:
      self.df['target'] = self.df[self.name1].shift(-29)
    
    self.df['resid'] = 0
    stl = STL(self.df[['date', self.name1]].set_index('date'), period=12)
    res = stl.fit()
    self.df['resid'] = res.resid.values

  def set_model_lgb(self):
    import lightgbm as lgb
    self.scaler = RobustScaler()
    self.df[self.feature] = self.scaler.fit_transform(self.df[self.feature])
    self.df_learn = self.df[self.df['target'].notnull()]
    self.X = self.df_learn[self.feature]
    self.y = self.df_learn['target']
    
    self.train_split = 1733
    self.valid_split = 1770
    
    self.X_train = self.X[:self.train_split]
    self.y_train = self.y[:self.train_split]
    self.X_valid = self.X[self.train_split:self.valid_split]
    self.y_valid = self.y[self.train_split:self.valid_split]
    self.X_test = self.X[self.valid_split:]
    self.y_test = self.y[self.valid_split:]

    self.train_ds = lgb.Dataset(self.X_train,  label = self.y_train)
    self.valid_df = lgb.Dataset(self.X_valid,  label = self.y_valid)

#     self.params= {
#                 'num_leaves':10000 ,
#                 'objective' :'regression',
#                 'metric':'mse'
#                 } 
    self.params = {'learning_rate': 0.01, 
          'max_depth': 6, 
          'boosting': 'gbdt', 
          'objective': 'regression', 
          'metric': 'mse', 
          'is_training_metric': True, 
          'num_leaves': 100, 
          'feature_fraction': 0.8, 
          'bagging_fraction': 0.8, 
          'bagging_freq': 5, 
          'num_threads':8
             }
    self.num_round = 1000
    
    self.model_lgb = lgb.train(self.params, self.train_ds, self.num_round, self.valid_df)

  def get_plot_lgb(self):  
    self.y_pred = self.model_lgb.predict(self.X_test)
    self.RMSE = mean_squared_error(self.y_test, self.y_pred) ** 0.5

    plt.figure(figsize=(20, 10), dpi=300)
    plt.title(self.name + ' 가격 예측 결과'+   '   RMSE : ' + str(self.RMSE)[:7])
    plt.ylabel(self.name + ' 가격')
    plt.plot(np.array(self.y_train), alpha = 0.9, label = 'Real')
    plt.plot(self.model_lgb.predict(self.X_train), alpha = 0.6, linestyle = "--", label = 'Predict')
    plt.legend()
    plt.show()
    self.RMSE.round(2)

  def get_price_lgb(self):
    # self.X_test = X_test[self.feature]
    self.price = self.model_lgb.predict(self.X_test)
    return self.price[0]

# %%
my_nong1 = Nong1(df, private2)

my_nong1.set_feature('토마토')

my_nong1.set_target(1)

# %%
my_nong1.set_model_lgb()
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000191 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1872
# [LightGBM] [Info] Number of data points in the train set: 1733, number of used features: 15
# [LightGBM] [Info] Start training from score 2176.669648
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's l2: 74478.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's l2: 74048.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's l2: 73541.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's l2: 73118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's l2: 72692.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's l2: 72366.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's l2: 82402.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's l2: 84389.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's l2: 83964.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 82462.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's l2: 81871.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's l2: 81140.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's l2: 80573.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's l2: 80443.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's l2: 79951.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's l2: 78817.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's l2: 78152.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's l2: 82602.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's l2: 81608.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l2: 81640.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's l2: 83458.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's l2: 91005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's l2: 89654.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's l2: 89594.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's l2: 89549
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's l2: 88726.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's l2: 88445
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's l2: 87580.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's l2: 87357.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l2: 87454.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's l2: 86754.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's l2: 86031.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's l2: 85319.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's l2: 84627.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's l2: 84052.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's l2: 83479.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's l2: 91430.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's l2: 90536.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's l2: 98773.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l2: 98276.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's l2: 98414.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's l2: 97207.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's l2: 105402
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's l2: 113929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's l2:
2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [408]	valid_0's l2: 89104.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [409]	valid_0's l2: 88281.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [410]	valid_0's l2: 87831.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [411]	valid_0's l2: 88000.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [412]	valid_0's l2: 87969.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [413]	valid_0's l2: 87187.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [414]	valid_0's l2: 86990
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [415]	valid_0's l2: 86922.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [416]	valid_0's l2: 86717.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [417]	valid_0's l2: 86156.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [418]	valid_0's l2: 85606.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [419]	valid_0's l2: 85562
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [420]	valid_0's l2: 85021.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [421]	valid_0's l2: 85142.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [422]	valid_0's l2: 85249.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [423]	valid_0's l2: 84787.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [424]	valid_0's l2: 85120.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [425]	valid_0's l2: 85312.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [426]	valid_0's l2: 84648.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [427]	valid_0's l2: 83999.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [428]	valid_0's l2: 83269.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [429]	valid_0's l2: 82645.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [430]	valid_0's l2: 82036.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [431]	valid_0's l2: 81783.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [432]	valid_0's l2: 81453.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [433]	valid_0's l2: 80970.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [434]	valid_0's l2: 80608.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [435]	valid_0's l2: 80377.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [436]	valid_0's l2: 80075.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [437]	valid_0's l2: 80004.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [438]	valid_0's l2: 79699.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [439]	valid_0's l2: 79963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [440]	valid_0's l2: 79893.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [441]	valid_0's l2: 79516.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [442]	valid_0's l2: 79146.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [443]	valid_0's l2: 78782.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [444]	valid_0's l2: 78426.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [445]	valid_0's l2: 78076.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [446]	valid_0's l2: 77551.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [447]	valid_0's l2: 77013.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [448]	valid_0's l2: 76488.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [449]	valid_0's l2: 75976.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	valid_0's l2: 75477.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [451]	valid_0's l2: 75265.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [452]	valid_0's l2: 74613.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [453]	valid_0's l2: 74660.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [454]	valid_0's l2: 74719.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [455]	valid_0's l2: 74728.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [456]	valid_0's l2: 74453.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [457]	valid_0's l2: 74710
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [458]	valid_0's l2: 74966.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [459]	valid_0's l2: 75223.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [460]	valid_0's l2: 75479.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [461]	valid_0's l2: 75100.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [462]	valid_0's l2: 74953.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [463]	valid_0's l2: 74530
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [464]	valid_0's l2: 74479.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [465]	valid_0's l2: 74063
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [466]	valid_0's l2: 74018.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [467]	valid_0's l2: 74124.8
# ...
# [845]	valid_0's l2: 55423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [846]	valid_0's l2: 55513.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [847]	valid_0's l2: 55509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [848]	valid_0's l2: 55534.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [849]	valid_0's l2: 55529.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	valid_0's l2: 55547.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [851]	valid_0's l2: 55533.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [852]	valid_0's l2: 55521.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [853]	valid_0's l2: 55508.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [854]	valid_0's l2: 55517
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [855]	valid_0's l2: 55504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [856]	valid_0's l2: 55506.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [857]	valid_0's l2: 55508.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [858]	valid_0's l2: 55510.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [859]	valid_0's l2: 55513.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [860]	valid_0's l2: 55515.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [861]	valid_0's l2: 55533.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [862]	valid_0's l2: 55554.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [863]	valid_0's l2: 55576.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [864]	valid_0's l2: 55601.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [865]	valid_0's l2: 55627.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [866]	valid_0's l2: 55604.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [867]	valid_0's l2: 55583.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [868]	valid_0's l2: 55563.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [869]	valid_0's l2: 55545.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [870]	valid_0's l2: 55579.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [871]	valid_0's l2: 55594.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [872]	valid_0's l2: 55610.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [873]	valid_0's l2: 55627.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [874]	valid_0's l2: 55665.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [875]	valid_0's l2: 55685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [876]	valid_0's l2: 55666.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [877]	valid_0's l2: 55699.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [878]	valid_0's l2: 55703.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [879]	valid_0's l2: 55685.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [880]	valid_0's l2: 55754.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [881]	valid_0's l2: 55772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [882]	valid_0's l2: 55790.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [883]	valid_0's l2: 55809.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [884]	valid_0's l2: 55833.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [885]	valid_0's l2: 55853.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [886]	valid_0's l2: 55718.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [887]	valid_0's l2: 55597.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [888]	valid_0's l2: 55419.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [889]	valid_0's l2: 55287.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [890]	valid_0's l2: 55170.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [891]	valid_0's l2: 55144.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [892]	valid_0's l2: 55120.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [893]	valid_0's l2: 55098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [894]	valid_0's l2: 55076.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [895]	valid_0's l2: 55056.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [896]	valid_0's l2: 55015.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [897]	valid_0's l2: 55031.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [898]	valid_0's l2: 55053.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [899]	valid_0's l2: 55075.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [900]	valid_0's l2: 55094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [901]	valid_0's l2: 55117.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [902]	valid_0's l2: 55141.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [903]	valid_0's l2: 55166.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [904]	valid_0's l2: 55192.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [905]	valid_0's l2: 55249.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [906]	valid_0's l2: 55274.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [907]	valid_0's l2: 55301.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [908]	valid_0's l2: 55329.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [909]	valid_0's l2: 55344.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [910]	valid_0's l2: 55375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [911]	valid_0's l2: 55463.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [912]	valid_0's l2: 55512
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [913]	valid_0's l2: 55547.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [914]	valid_0's l2: 55556.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [915]	valid_0's l2: 55470.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [916]	valid_0's l2: 55386.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [917]	valid_0's l2: 55435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [918]	valid_0's l2: 55484.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [919]	valid_0's l2: 55514
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [920]	valid_0's l2: 55386.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [921]	valid_0's l2: 55441.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [922]	valid_0's l2: 55231.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [923]	valid_0's l2: 55113.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [924]	valid_0's l2: 54964.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [925]	valid_0's l2: 54850.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [926]	valid_0's l2: 54886.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [927]	valid_0's l2: 54922.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [928]	valid_0's l2: 54959.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [929]	valid_0's l2: 54997.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [930]	valid_0's l2: 55035.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [931]	valid_0's l2: 55105.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [932]	valid_0's l2: 55187.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [933]	valid_0's l2: 55270.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [934]	valid_0's l2: 55291.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [935]	valid_0's l2: 55367.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [936]	valid_0's l2: 55108.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [937]	valid_0's l2: 54918.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [938]	valid_0's l2: 54662.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [939]	valid_0's l2: 54410.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [940]	valid_0's l2: 54441.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [941]	valid_0's l2: 54612.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [942]	valid_0's l2: 54669.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [943]	valid_0's l2: 54829.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [944]	valid_0's l2: 55049.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [945]	valid_0's l2: 55045.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [946]	valid_0's l2: 55016.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [947]	valid_0's l2: 54987.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [948]	valid_0's l2: 55071.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [949]	valid_0's l2: 55041.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	valid_0's l2: 55012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [951]	valid_0's l2: 55046.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [952]	valid_0's l2: 55094.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [953]	valid_0's l2: 55031.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [954]	valid_0's l2: 55066.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [955]	valid_0's l2: 55100.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [956]	valid_0's l2: 55051.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [957]	valid_0's l2: 55068.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [958]	valid_0's l2: 55079.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [959]	valid_0's l2: 55016
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [960]	valid_0's l2: 54991.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [961]	valid_0's l2: 54906
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [962]	valid_0's l2: 54824.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [963]	valid_0's l2: 54747.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [964]	valid_0's l2: 54673.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [965]	valid_0's l2: 54676.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [966]	valid_0's l2: 54578.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [967]	valid_0's l2: 54659.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [968]	valid_0's l2: 54561.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [969]	valid_0's l2: 54645.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [970]	valid_0's l2: 54732.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [971]	valid_0's l2: 54728.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [972]	valid_0's l2: 54724.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [973]	valid_0's l2: 54701.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [974]	valid_0's l2: 54472.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [975]	valid_0's l2: 54568.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [976]	valid_0's l2: 54432.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [977]	valid_0's l2: 54486.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [978]	valid_0's l2: 54540.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [979]	valid_0's l2: 54596
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [980]	valid_0's l2: 54651.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [981]	valid_0's l2: 54586.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [982]	valid_0's l2: 54436.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [983]	valid_0's l2: 54374.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [984]	valid_0's l2: 54312.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [985]	valid_0's l2: 54254.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [986]	valid_0's l2: 54248.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [987]	valid_0's l2: 54233.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [988]	valid_0's l2: 54232.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [989]	valid_0's l2: 54176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [990]	valid_0's l2: 54169.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [991]	valid_0's l2: 54169.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [992]	valid_0's l2: 54172.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [993]	valid_0's l2: 54160.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [994]	valid_0's l2: 54147.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [995]	valid_0's l2: 54206.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [996]	valid_0's l2: 54110.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [997]	valid_0's l2: 54040.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [998]	valid_0's l2: 54054.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [999]	valid_0's l2: 54032.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	valid_0's l2: 54020.8

# %%
my_nong1.get_plot_lgb()

# %% [markdown]
# ### 모델 실행

# %%
from sympy import Shi


weeks = [1, 2, 4]
features = ['대파', '깻잎', '팽이버섯', '토마토', '캠벨얼리'] 

week1=[]
week2=[]
week4=[]

for week in weeks:
  print(week)
  for feature in features:
    my_nong1 = Nong1(df, private2)
    my_nong1.set_feature(feature)
    my_nong1.set_target(week)
    print(my_nong1.set_target(week))
    my_nong1.set_model_lgb()
    if week == 1:
      week1.append(my_nong1.get_price_lgb())
    if week == 2:
      week2.append(my_nong1.get_price_lgb())
    if week == 4:
      week4.append(my_nong1.get_price_lgb())
    print(feature)
# Out:
# 1
# None
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000434 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1872
# [LightGBM] [Info] Number of data points in the train set: 1733, number of used features: 15
# [LightGBM] [Info] Start training from score 1365.433930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's l2: 368199
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's l2: 362019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's l2: 356397
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's l2: 350469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's l2: 344078
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's l2: 338649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's l2: 329878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's l2: 321359
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's l2: 316572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 311717
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's l2: 306896
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's l2: 301952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's l2: 297720
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's l2: 294074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's l2: 289333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's l2:
+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [968]	valid_0's l2: 1.89247e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [969]	valid_0's l2: 1.89153e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [970]	valid_0's l2: 1.89125e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [971]	valid_0's l2: 1.88745e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [972]	valid_0's l2: 1.88359e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [973]	valid_0's l2: 1.88331e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [974]	valid_0's l2: 1.88694e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [975]	valid_0's l2: 1.88296e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [976]	valid_0's l2: 1.88292e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [977]	valid_0's l2: 1.88736e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [978]	valid_0's l2: 1.88838e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [979]	valid_0's l2: 1.89189e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [980]	valid_0's l2: 1.89626e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [981]	valid_0's l2: 1.89172e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [982]	valid_0's l2: 1.89173e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [983]	valid_0's l2: 1.89004e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [984]	valid_0's l2: 1.88558e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [985]	valid_0's l2: 1.88198e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [986]	valid_0's l2: 1.8764e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [987]	valid_0's l2: 1.87611e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [988]	valid_0's l2: 1.87583e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [989]	valid_0's l2: 1.87516e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [990]	valid_0's l2: 1.86966e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [991]	valid_0's l2: 1.86926e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [992]	valid_0's l2: 1.86834e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [993]	valid_0's l2: 1.86569e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [994]	valid_0's l2: 1.86565e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [995]	valid_0's l2: 1.86561e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [996]	valid_0's l2: 1.86655e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [997]	valid_0's l2: 1.86749e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [998]	valid_0's l2: 1.86796e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [999]	valid_0's l2: 1.86907e+06
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	valid_0's l2: 1.87017e+06
# 캠벨얼리

# %%
week1, week2, week4
# Out:
# ([1759.0212300275857,
#   5885.053852308494,
#   1428.2046041786555,
#   1818.9505470704664,
#   4027.5705253058277],
#  [1778.6409392877786,
#   5123.3023925714715,
#   1636.1310234437428,
#   2152.550452931299,
#   4305.205154240988],
#  [1782.094329070148,
#   5611.6918607868465,
#   1547.3622376992478,
#   2419.562981518221,
#   3669.499877442395])

# %%
from pyrsistent import b


date = '20201106'

feature = [ '대파_가격(원/kg)', '깻잎_가격(원/kg)','팽이버섯_가격(원/kg)', '토마토_가격(원/kg)', '캠벨얼리_가격(원/kg)']
submission = submission.set_index('예측대상일자')
submission.loc[datetime.strptime(date, "%Y%m%d").strftime("%Y-%m-%d")+'+1week', feature] = week1
submission.loc[datetime.strptime(date, "%Y%m%d").strftime("%Y-%m-%d")+'+2week', feature] = week2
submission.loc[datetime.strptime(date, "%Y%m%d").strftime("%Y-%m-%d")+'+4week', feature] = week4
submission.reset_index(drop=False, inplace=True)
title = 'submission' + date + '.csv'

# %%
submission.drop(columns=['배추_가격(원/kg)', '무_가격(원/kg)', '양파_가격(원/kg)', '건고추_가격(원/kg)',
       '마늘_가격(원/kg)',  '얼갈이배추_가격(원/kg)', '양배추_가격(원/kg)',
       '시금치_가격(원/kg)', '미나리_가격(원/kg)', '당근_가격(원/kg)', '파프리카_가격(원/kg)', '새송이_가격(원/kg)', 
       '청상추_가격(원/kg)', '백다다기_가격(원/kg)', '애호박_가격(원/kg)','샤인마스캇_가격(원/kg)'], inplace= True)

# %%
submission2 = submission[228:].round(2)
submission2
# Out:
#                예측대상일자  대파_가격(원/kg)  깻잎_가격(원/kg)  팽이버섯_가격(원/kg)  토마토_가격(원/kg)  \
# 228  2020-11-06+1week      1759.02      5885.05        1428.20       1818.95
# 229  2020-11-06+2week      1778.64      5123.30        1636.13       2152.55
# 230  2020-11-06+4week      1782.09      5611.69        1547.36       2419.56
#
#      캠벨얼리_가격(원/kg)
# 228        4027.57
# 229        4305.21
# 230        3669.50

# %%
# 실제값과 비교! 
private2 = private2[['date','요일','대파_가격(원/kg)', '깻잎_가격(원/kg)','팽이버섯_가격(원/kg)', '토마토_가격(원/kg)', '캠벨얼리_가격(원/kg)']]
private2_week = private2[::7]
private2_week[1:5]
# Out:
#          date   요일  대파_가격(원/kg)  깻잎_가격(원/kg)  팽이버섯_가격(원/kg)  토마토_가격(원/kg)  \
# 7  2020-11-13  금요일       2374.0       5013.0         1532.0        2305.0
# 14 2020-11-20  금요일       2319.0       3316.0         1471.0        2015.0
# 21 2020-11-27  금요일       1841.0       3129.0         1294.0        1847.0
# 28 2020-12-04  금요일       1543.0       4326.0         1255.0        1814.0
#
#     캠벨얼리_가격(원/kg)
# 7          3579.0
# 14         4859.0
# 21         4353.0
# 28         4063.0

# %%
submission2.to_csv(processed_path + title, encoding='utf-8-sig', index = False)
