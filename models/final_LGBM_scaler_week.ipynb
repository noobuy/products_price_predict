# %% [markdown]
# | EDA dataframe      | Description |due|
# | ----------- | ----------- |----------- |
# | grape_df  | 캠벨얼리 가격/거래량  |20190101 ~ 20201104|
# | df      | grape_train + shinemuscat_train       | 20190101 ~ 2020928|
#
#
# **train accuracy / test accuracy 의 차이 비교 overfitting = 20% 이상 (10~20%)**

# %% [markdown]
# https://dacon.io/competitions/official/235801/codeshare/4063?page=1&dtype=recent
#
# [lgbm 튜닝](https://dacon.io/competitions/official/235698/talkboard/404322)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic'

from numpy import array
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import matplotlib as mpl
from IPython.core.display import display, HTML
from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from statsmodels.tsa.seasonal import seasonal_decompose, STL
import urllib.request
import requests
import json
import datetime
import os
from datetime import datetime
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')
# Out:
# /var/folders/lm/z4n_2b8s6rj3_vv57sg789kc0000gn/T/ipykernel_67494/2031877544.py:10: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
# iMAC

raw_path = '/Users/cge/Documents/yeardream/project/kurly/products_price_predict/data/raw/'
processed_path = '/Users/cge/Documents/yeardream/project/kurly/products_price_predict/data/processed/'

# %%
# Macbook
    
# raw_path = '/Users/goeun/Documents/YearDream/ProJect/kurly_project/products_price_predict/data/raw/'
# processed_path = '/Users/goeun/Documents/YearDream/ProJect/kurly_project/products_price_predict/data/processed/'

# %%
grape = pd.read_csv(processed_path+'캠벨얼리_전처리후.csv')
mushroom = pd.read_csv(processed_path+'팽이버섯_전처리후.csv')
tomato = pd.read_csv(processed_path+'토마토_전처리후.csv', index_col = 0)
welsh = pd.read_csv(processed_path+'대파_전처리후.csv', index_col = 0)
plant = pd.read_csv(processed_path+'깻잎_전처리후.csv', index_col = 0)

private = pd.read_csv(raw_path+'private_data.csv')
submission = pd.read_csv(raw_path+'sample_submission.csv')

print(grape.shape)
print(mushroom.shape)
print(private.shape)
print(submission.shape)
# Out:
# (1770, 9)
# (1770, 9)
# (291, 44)
# (228, 22)

# %%
grape[grape['캠벨얼리_가격(원/kg)'] > 1]['캠벨얼리_가격(원/kg)'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
tomato.drop(columns=['계절_가을', '계절_겨울', '계절_봄', '계절_여름'], inplace=True)
welsh.drop(columns=['계절_가을', '계절_겨울', '계절_봄', '계절_여름'], inplace=True)
plant.drop(columns=['계절_가을', '계절_겨울', '계절_봄', '계절_여름'], inplace=True)

# %%
df = pd.merge(grape, mushroom, on=['date', '요일', '계절'])
df = pd.merge(df, tomato, on =['date', '요일'] )
df = pd.merge(df, welsh, on = ['date','요일'])
df = pd.merge(df, plant, on = ['date','요일'])

train = df[:1733]
test = df[1733:]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1770 entries, 0 to 1769
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              1770 non-null   object
#  1   요일                1770 non-null   object
#  2   캠벨얼리_거래량(kg)      1770 non-null   float64
#  3   캠벨얼리_가격(원/kg)     1770 non-null   float64
#  4   캠벨얼리_거래량의_1주전_평균  1770 non-null   float64
#  5   캠벨얼리_가격의_1주전_평균   1770 non-null   float64
#  6   캠벨얼리_거래량의_2주전_평균  1770 non-null   float64
#  7   캠벨얼리_가격의_2주전_평균   1770 non-null   float64
#  8   계절                1770 non-null   int64
#  9   팽이버섯_거래량(kg)      1770 non-null   float64
#  10  팽이버섯_가격(원/kg)     1770 non-null   float64
#  11  팽이버섯_거래량의_1주전_평균  1770 non-null   float64
#  12  팽이버섯_가격의_1주전_평균   1770 non-null   float64
#  13  팽이버섯_거래량의_2주전_평균  1770 non-null   float64
#  14  팽이버섯_가격의_2주전_평균   1770 non-null   float64
#  15  토마토_거래량(kg)       1770 non-null   float64
#  16  토마토_가격(원/kg)      1770 non-null   float64
#  17  토마토_거래량의_1주전_평균   1770 non-null   float64
#  18  토마토_가격의_1주전_평균    1770 non-null   float64
#  19  토마토_거래량의_2주전_평균   1770 non-null   float64
#  20  토마토_가격의_2주전_평균    1770 non-null   float64
#  21  대파_거래량(kg)        1770 non-null   float64
#  22  대파_가격(원/kg)       1770 non-null   float64
#  23  대파_거래량의_1주전_평균    1770 non-null   float64
#  24  대파_가격의_1주전_평균     1770 non-null   float64
#  25  대파_거래량의_2주전_평균    1770 non-null   float64
#  26  대파_가격의_2주전_평균     1770 non-null   float64
#  27  깻잎_거래량(kg)        1770 non-null   float64
#  28  깻잎_가격(원/kg)       1770 non-null   float64
#  29  깻잎_거래량의_1주전_평균    1770 non-null   float64
#  30  깻잎_가격의_1주전_평균     1770 non-null   float64
#  31  깻잎_거래량의_2주전_평균    1770 non-null   float64
#  32  깻잎_가격의_2주전_평균     1770 non-null   float64
# dtypes: float64(30), int64(1), object(2)
# memory usage: 470.2+ KB

# %% [markdown]
# # LGBM(LightGBM)

# %% [markdown]
# ## 대파 & 깻잎 & 팽이버섯 & 토마토 & 캠벨얼리

# %%
private2 = private.copy()
private2 = private2[['date','대파_거래량(kg)', '대파_가격(원/kg)', '깻잎_거래량(kg)', '깻잎_가격(원/kg)',
               '팽이버섯_거래량(kg)', '팽이버섯_가격(원/kg)', '토마토_거래량(kg)', '토마토_가격(원/kg)', '캠벨얼리_거래량(kg)', '캠벨얼리_가격(원/kg)',]]

# %%
private2['date'] = private2.date.astype(str).str.replace('-','')
private2['date'] = pd.to_datetime(private2.date, format='%Y%m%d')


t = ['월요일', '화요일', '수요일', '목요일', '금요일', '토요일', '일요일']
private2['요일'] = 0
temp = []
for i in range(len(private2)):
      temp.append(t[int(private2['date'][i].weekday())])
private2['요일'] = temp

private2 = private2[['date', '요일','대파_거래량(kg)', '대파_가격(원/kg)', '깻잎_거래량(kg)', '깻잎_가격(원/kg)',
               '팽이버섯_거래량(kg)', '팽이버섯_가격(원/kg)', '토마토_거래량(kg)', '토마토_가격(원/kg)', '캠벨얼리_거래량(kg)', '캠벨얼리_가격(원/kg)',]]

# %%
class Nong1:
    

  def __init__(self, df, test):
    self.df = df
    self.test = test
    self.df = pd.concat([self.df, self.test], axis=0).reset_index(drop=True)
    self.df = self.df[1:].replace(0, np.NaN)
    self.df = self.df.interpolate().fillna(0)
    self.df.date = pd.to_datetime(self.df.date)
    self.df = pd.concat([self.df, pd.get_dummies(self.df['요일'])], axis=1)
    self.feature = self.df.columns[2:]
    self.df = self.df.reset_index(drop=True)

  def set_feature(self,name):
    self.name = name
    self.name1 = name+ "_가격(원/kg)"
    self.name2 = name+ "_거래량(kg)"
    self.name3 = name+ "_거래량의_1주전_평균"
    self.name4 = name+ '_가격의_1주전_평균'
    self.name5 = name+ '_거래량의_2주전_평균'
    self.name6 = name+ '_가격의_2주전_평균'
    self.name7 = '계절'
    self.feature = [self.name1, self.name2, self.name3, self.name4, self.name5, self.name6, self.name7, '금요일',   '목요일',   '수요일',   '월요일',   '일요일',   '토요일',   '화요일', 'resid']

  def set_target(self,week):
    if week == 1:
      self.df['target'] = self.df[self.name1].shift(-8)
    elif week == 2:
      self.df['target'] = self.df[self.name1].shift(-15)
    elif week == 4:
      self.df['target'] = self.df[self.name1].shift(-29)
    
    self.df['resid'] = 0
    stl = STL(self.df[['date', self.name1]].set_index('date'), period=12)
    res = stl.fit()
    self.df['resid'] = res.resid.values

  def set_model_lgb(self):
    import lightgbm as lgb
    self.scaler = RobustScaler()
    self.df[self.feature] = self.scaler.fit_transform(self.df[self.feature])
    self.df_learn = self.df[self.df['target'].notnull()]
    self.X = self.df_learn[self.feature]
    self.y = self.df_learn['target']
    
    self.train_split = 1733
    self.valid_split = 1770
    
    self.X_train = self.X[:self.train_split]
    self.y_train = self.y[:self.train_split]
    self.X_valid = self.X[self.train_split:self.valid_split]
    self.y_valid = self.y[self.train_split:self.valid_split]
    self.X_test = self.X[self.valid_split:]
    self.y_test = self.y[self.valid_split:]

    self.train_ds = lgb.Dataset(self.X_train,  label = self.y_train)
    self.valid_df = lgb.Dataset(self.X_valid,  label = self.y_valid)

#     self.params= {
#                 'num_leaves':10000 ,
#                 'objective' :'regression',
#                 'metric':'mse'
#                 } 
    self.params = {'learning_rate': 0.01, 
          'max_depth': 6, 
          'boosting': 'gbdt', 
          'objective': 'regression', 
          'metric': 'mse', 
          'is_training_metric': True, 
          'num_leaves': 100, 
          'feature_fraction': 0.8, 
          'bagging_fraction': 0.8, 
          'bagging_freq': 5, 
          'num_threads':8
             }
    self.num_round = 1000
    
    self.model_lgb = lgb.train(self.params, self.train_ds, self.num_round, self.valid_df)

  def get_plot_lgb(self):  
    self.y_pred = self.model_lgb.predict(self.X_test)
    print(self.X_test.shape, self.y_pred.shape)
    self.RMSE = mean_squared_error(self.y_test, self.y_pred) ** 0.5

    plt.figure(figsize=(20, 10), dpi=300)
    plt.title(self.name + ' 가격 예측 결과'+   '   RMSE : ' + str(self.RMSE)[:7])
    plt.ylabel(self.name + ' 가격')
    plt.plot(np.array(self.y_test), alpha = 0.9, label = 'Real')
    plt.plot(self.model_lgb.predict(self.X_test), alpha = 0.6, linestyle = "--", label = 'Predict')
    plt.legend()
    plt.show()
    self.RMSE.round(2)

  def get_price_lgb(self):
    # self.X_test = X_test[self.feature]
    self.price = self.model_lgb.predict(self.X_test)
    return self.price[0]

# %%
my_nong1 = Nong1(df, private2)

# '대파', '깻잎', '팽이버섯', '토마토', '캠벨얼리'

my_nong1.set_feature('캠벨얼리')

my_nong1.set_target(1)

# %%
my_nong1.set_model_lgb()
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000383 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1856
# [LightGBM] [Info] Number of data points in the train set: 1733, number of used features: 15
# [LightGBM] [Info] Start training from score 3900.680479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's l2: 833381
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's l2: 837591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's l2: 841771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's l2: 845920
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's l2: 846989
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's l2: 840761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's l2: 841632
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's l2: 842495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's l2: 836471
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 822699
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's l2: 826121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's l2: 814357
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's l2: 817733
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's l2: 821082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's l2: 809753
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's l2: 809168
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's l2: 805195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's l2: 809524
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's l2: 813823
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l2: 813096
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's l2: 817434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's l2: 818609
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's l2: 813616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's l2: 802041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's l2: 797438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's l2: 792256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's l2: 784537
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's l2: 779882
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's l2: 775606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l2: 770463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's l2: 773893
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's l2: 765483
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's l2: 768830
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's l2: 772151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's l2: 775447
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's l2: 764499
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's l2: 768067
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's l2: 770242
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's l2: 773753
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l2: 775871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's l2: 771798
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's l2: 767869
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's l2: 787795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's l2: 807800
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's l2: 803892
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's l2: 796876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's l2: 792853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's l2: 793404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's l2: 789507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's l2: 790043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's l2: 787952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's l2: 789999
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's l2: 786654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's l2: 788657
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's l2: 786928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's l2: 780836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's l2: 776094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's l2: 769872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's l2: 769638
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's l2: 763804
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's l2: 764240
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	valid_0's l2: 756819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's l2: 749208
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's l2: 741709
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's l2: 737458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's l2: 734661
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's l2: 748768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's l2: 744687
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's l2: 741891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's l2: 738462
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's l2: 733241
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's l2: 727575
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's l2: 722016
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's l2: 717039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's l2: 711817
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's l2: 709271
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's l2: 709012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's l2: 708803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0's l2: 705108
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's l2: 699235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [81]	valid_0's l2: 697821
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [82]	valid_0's l2: 696427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	valid_0's l2: 693110
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	valid_0's l2: 692705
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	valid_0's l2: 691541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	valid_0's l2: 689480
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	valid_0's l2: 688523
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	valid_0's l2: 686512
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	valid_0's l2: 683867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	valid_0's l2: 680409
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	valid_0's l2: 674926
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	valid_0's l2: 669526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [93]	valid_0's l2: 671306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	valid_0's l2: 670461
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	valid_0's l2: 667789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	valid_0's l2: 662512
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	valid_0's l2: 660073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	valid_0's l2: 657792
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	valid_0's l2: 656558
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's l2: 656850
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	valid_0's l2: 666914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	valid_0's l2: 664309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	valid_0's l2: 662754
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	valid_0's l2: 660203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	valid_0's l2: 658521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	valid_0's l2: 657645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	valid_0's l2: 656216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	valid_0's l2: 652854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	valid_0's l2: 649615
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	valid_0's l2: 648774
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	valid_0's l2: 646617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [112]	valid_0's l2: 648892
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	valid_0's l2: 646778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [114]	valid_0's l2: 643450
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	valid_0's l2: 641301
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	valid_0's l2: 650468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [117]	valid_0's l2: 649052
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	valid_0's l2: 646722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	valid_0's l2: 642208
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	valid_0's l2: 651090
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	valid_0's l2: 649297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	valid_0's l2: 645154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	valid_0's l2: 640095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	valid_0's l2: 639447
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's l2: 635548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	valid_0's l2: 631335
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [127]	valid_0's l2:

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [891]	valid_0's l2: 496382
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [892]	valid_0's l2: 496487
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [893]	valid_0's l2: 496781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [894]	valid_0's l2: 496830
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [895]	valid_0's l2: 496930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [896]	valid_0's l2: 496827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [897]	valid_0's l2: 496733
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [898]	valid_0's l2: 496599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [899]	valid_0's l2: 496532
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [900]	valid_0's l2: 496450
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [901]	valid_0's l2: 496812
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [902]	valid_0's l2: 498987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [903]	valid_0's l2: 499028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [904]	valid_0's l2: 499434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [905]	valid_0's l2: 501592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [906]	valid_0's l2: 501782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [907]	valid_0's l2: 501689
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [908]	valid_0's l2: 501587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [909]	valid_0's l2: 501216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [910]	valid_0's l2: 501406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [911]	valid_0's l2: 501475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [912]	valid_0's l2: 501338
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [913]	valid_0's l2: 501408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [914]	valid_0's l2: 501232
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [915]	valid_0's l2: 501233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [916]	valid_0's l2: 501233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [917]	valid_0's l2: 501266
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [918]	valid_0's l2: 501228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [919]	valid_0's l2: 501191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [920]	valid_0's l2: 501194
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [921]	valid_0's l2: 501236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [922]	valid_0's l2: 501277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [923]	valid_0's l2: 501318
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [924]	valid_0's l2: 501486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [925]	valid_0's l2: 501739
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [926]	valid_0's l2: 501865
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [927]	valid_0's l2: 501991
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [928]	valid_0's l2: 502116
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [929]	valid_0's l2: 502137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [930]	valid_0's l2: 504040
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [931]	valid_0's l2: 504535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [932]	valid_0's l2: 504687
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [933]	valid_0's l2: 504838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [934]	valid_0's l2: 505610
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [935]	valid_0's l2: 506143
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [936]	valid_0's l2: 505999
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [937]	valid_0's l2: 505761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [938]	valid_0's l2: 505621
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [939]	valid_0's l2: 503871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [940]	valid_0's l2: 503697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [941]	valid_0's l2: 503661
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [942]	valid_0's l2: 503624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [943]	valid_0's l2: 503822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [944]	valid_0's l2: 503316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [945]	valid_0's l2: 503511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [946]	valid_0's l2: 502455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [947]	valid_0's l2: 502389
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [948]	valid_0's l2: 502595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [949]	valid_0's l2: 502634
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	valid_0's l2: 502511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [951]	valid_0's l2: 502681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [952]	valid_0's l2: 502637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [953]	valid_0's l2: 502534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [954]	valid_0's l2: 502433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [955]	valid_0's l2: 502333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [956]	valid_0's l2: 502246
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [957]	valid_0's l2: 502264
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [958]	valid_0's l2: 502108
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [959]	valid_0's l2: 502114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [960]	valid_0's l2: 502096
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [961]	valid_0's l2: 502291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [962]	valid_0's l2: 502485
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [963]	valid_0's l2: 502676
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [964]	valid_0's l2: 502839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [965]	valid_0's l2: 503028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [966]	valid_0's l2: 499559
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [967]	valid_0's l2: 496138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [968]	valid_0's l2: 492766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [969]	valid_0's l2: 492863
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [970]	valid_0's l2: 489541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [971]	valid_0's l2: 489476
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [972]	valid_0's l2: 489411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [973]	valid_0's l2: 489457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [974]	valid_0's l2: 489392
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [975]	valid_0's l2: 489327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [976]	valid_0's l2: 489171
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [977]	valid_0's l2: 489089
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [978]	valid_0's l2: 489569
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [979]	valid_0's l2: 489489
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [980]	valid_0's l2: 489474
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [981]	valid_0's l2: 489550
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [982]	valid_0's l2: 489620
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [983]	valid_0's l2: 489594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [984]	valid_0's l2: 489664
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [985]	valid_0's l2: 490674
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [986]	valid_0's l2: 490644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [987]	valid_0's l2: 490711
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [988]	valid_0's l2: 490592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [989]	valid_0's l2: 490512
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [990]	valid_0's l2: 490511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [991]	valid_0's l2: 490498
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [992]	valid_0's l2: 490563
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [993]	valid_0's l2: 490706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [994]	valid_0's l2: 492788
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [995]	valid_0's l2: 494861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [996]	valid_0's l2: 494984
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [997]	valid_0's l2: 495066
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [998]	valid_0's l2: 495259
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [999]	valid_0's l2: 494286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	valid_0's l2: 493469

# %%
my_nong1.get_plot_lgb()
# Out:
# (282, 15) (282,)

# %% [markdown]
# ### 모델 실행

# %%
from sympy import Shi


weeks = [1, 2, 4]
features = ['대파', '깻잎', '팽이버섯', '토마토', '캠벨얼리'] 

week1=[]
week2=[]
week4=[]

for week in weeks:
  print(week)
  for feature in features:
    my_nong1 = Nong1(df, private2)
    my_nong1.set_feature(feature)
    my_nong1.set_target(week)
    print(my_nong1.set_target(week))
    my_nong1.set_model_lgb()
    if week == 1:
      week1.append(my_nong1.get_price_lgb())
    if week == 2:
      week2.append(my_nong1.get_price_lgb())
    if week == 4:
      week4.append(my_nong1.get_price_lgb())
    print(feature)
# Out:
# 1
# None
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002740 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1871
# [LightGBM] [Info] Number of data points in the train set: 1733, number of used features: 15
# [LightGBM] [Info] Start training from score 1368.546740
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's l2: 868994
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's l2: 854085
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's l2: 841901
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's l2: 829957
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's l2: 818249
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's l2: 804307
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's l2: 793952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's l2: 780853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's l2: 770384
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 759440
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's l2: 748300
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's l2: 737507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's l2: 726781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's l2: 716741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's l2: 705302
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's l2: 694235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's l2: 685380
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's l2: 675606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's l2: 665114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l2: 654828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's l2: 644512
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's l2: 634477
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's l2: 624746
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's l2: 615929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's l2: 605482
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's l2: 595666
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's l2: 585749
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's l2: 576023
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's l2: 567248
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l2: 557872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's l2: 548362
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's l2: 539082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's l2: 531737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's l2: 523318
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's l2: 515701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's l2: 507661
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's l2: 500501
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's l2: 494846
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's l2: 487932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l2: 481157
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's l2: 475031
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's l2: 469330
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's l2: 462872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's l2: 456533
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's l2: 450404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's l2: 442927
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's l2: 438039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's l2: 430381
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's l2: 425681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's l2: 419899
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's l2: 413949
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's l2: 407867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's l2: 402121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's l2: 396543
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's l2: 390001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's l2: 386389
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's l2: 381532
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's l2: 377770
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's l2: 372952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's l2: 369297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's l2: 365152
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	valid_0's l2: 359460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's l2: 353975
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's l2: 348510
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's l2: 344565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's l2: 340430
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's l2: 335916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's l2: 331814
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's l2: 328051
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's l2: 324321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's l2: 320504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's l2: 316156
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's l2: 313159
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's l2: 308447
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's l2: 304429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's l2: 301161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's l2: 297426
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's l2: 293930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0's l2: 290327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's l2: 286993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [81]	valid_0's l2: 285102
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [82]	valid_0's l2: 281770
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	valid_0's l2: 277315
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	valid_0's l2: 275558
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	valid_0's l2: 272408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	valid_0's l2: 269456
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	valid_0's l2: 266566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	valid_0's l2: 263751
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	valid_0's l2: 260456
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	valid_0's l2: 257463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	valid_0's l2: 253808
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	valid_0's l2: 250438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [93]	valid_0's l2: 247804
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	valid_0's l2: 244550
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	valid_0's l2: 241693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	valid_0's l2: 238100
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	valid_0's l2: 234552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	valid_0's l2: 231761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	valid_0's l2: 229025
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's l2: 226750
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	valid_0's l2: 224792
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	valid_0's l2: 221900
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	valid_0's l2: 219758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	valid_0's l2: 217337
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	valid_0's l2: 214600
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	valid_0's l2: 212471
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	valid_0's l2: 210383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	valid_0's l2: 208826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	valid_0's l2: 206462
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	valid_0's l2: 204227
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	valid_0's l2: 200684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [112]	valid_0's l2: 198990
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	valid_0's l2: 196440
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [114]	valid_0's l2: 194205
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	valid_0's l2: 191744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	valid_0's l2: 190261
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [117]	valid_0's l2: 188747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	valid_0's l2: 187611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	valid_0's l2: 185771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	valid_0's l2: 184318
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	valid_0's l2: 182864
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	valid_0's l2: 181028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	valid_0's l2: 179234
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	valid_0's l2: 178118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's l2: 176658
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	valid_0's l2: 174723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [127]	valid_0's l2: 172666
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [128]	valid_0's l2: 170790
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [129]	valid_0's l2: 169467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	valid_0's l2: 167512
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	valid_0's l2: 166033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	valid_0's l2: 164903
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	valid_0's l2: 163609
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	valid_0's l2: 162253
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [135]	valid_0's l2: 161004
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's l2: 159635
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	valid_0's l2: 158316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	valid_0's l2: 157020
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	valid_0's l2: 156129
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	valid_0's l2: 154932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	valid_0's l2: 153470
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	valid_0's l2: 152015
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	valid_0's l2: 150473
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	valid_0's l2: 149695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	valid_0's l2: 148311
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	valid_0's l2: 147081
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [147]	valid_0's l2: 145872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	valid_0's l2: 144684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [149]	valid_0's l2: 143517
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	valid_0's l2: 142999
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [151]	valid_0's l2: 141968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [152]	valid_0's l2: 140827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	valid_0's l2: 140169
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	valid_0's l2: 139218
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	valid_0's l2: 138968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	valid_0's l2: 137124
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [157]	valid_0's l2: 135776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [158]	valid_0's l2: 135117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [159]	valid_0's l2: 133807
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	valid_0's l2: 132660
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [161]	valid_0's l2: 132422
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [162]	valid_0's l2: 131531
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [163]	valid_0's l2: 130690
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [164]	valid_0's l2: 129644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	valid_0's l2: 128993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [166]	valid_0's l2: 128627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	valid_0's l2: 127555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [168]	valid_0's l2: 126504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [169]	valid_0's l2: 125876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [170]	valid_0's l2: 125090
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [171]	valid_0's l2: 124744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [172]	valid_0's l2: 123690
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	valid_0's l2: 123418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [174]	valid_0's l2: 123097
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [175]	valid_0's l2: 122635
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	valid_0's l2: 121947
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [177]	valid_0's l2: 121217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [178]	valid_0's l2: 121073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [179]	valid_0's l2: 120848
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	valid_0's l2: 120829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [181]	valid_0's l2: 120269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	valid_0's l2: 119399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [183]	valid_0's l2: 118978
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [184]	valid_0's l2: 118460
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	valid_0's l2: 117634
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	valid_0's l2: 116889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [187]	valid_0's l2: 116075
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [188]	valid_0's l2: 115614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [189]	valid_0's l2: 114830
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [190]	valid_0's l2: 114130
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	valid_0's l2: 113289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [192]	valid_0's l2: 112499
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [193]	valid_0's l2: 111687
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	valid_0's l2: 110926
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [195]	valid_0's l2: 110161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [196]	valid_0's l2: 110004
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	valid_0's l2: 109833
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [198]	valid_0's l2: 109302
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [199]	valid_0's l2:

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [925]	valid_0's l2: 890623
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [926]	valid_0's l2: 889976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [927]	valid_0's l2: 889341
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [928]	valid_0's l2: 889070
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [929]	valid_0's l2: 889550
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [930]	valid_0's l2: 889554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [931]	valid_0's l2: 887930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [932]	valid_0's l2: 888725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [933]	valid_0's l2: 889520
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [934]	valid_0's l2: 889106
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [935]	valid_0's l2: 889659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [936]	valid_0's l2: 889720
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [937]	valid_0's l2: 889789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [938]	valid_0's l2: 889754
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [939]	valid_0's l2: 888575
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [940]	valid_0's l2: 888634
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [941]	valid_0's l2: 888592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [942]	valid_0's l2: 888551
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [943]	valid_0's l2: 888621
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [944]	valid_0's l2: 888709
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [945]	valid_0's l2: 888797
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [946]	valid_0's l2: 888820
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [947]	valid_0's l2: 888803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [948]	valid_0's l2: 888492
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [949]	valid_0's l2: 888483
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	valid_0's l2: 889603
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [951]	valid_0's l2: 887848
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [952]	valid_0's l2: 886118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [953]	valid_0's l2: 886438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [954]	valid_0's l2: 884744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [955]	valid_0's l2: 885680
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [956]	valid_0's l2: 881953
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [957]	valid_0's l2: 882677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [958]	valid_0's l2: 883397
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [959]	valid_0's l2: 883264
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [960]	valid_0's l2: 883971
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [961]	valid_0's l2: 883792
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [962]	valid_0's l2: 883616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [963]	valid_0's l2: 883432
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [964]	valid_0's l2: 883045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [965]	valid_0's l2: 883145
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [966]	valid_0's l2: 883579
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [967]	valid_0's l2: 884001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [968]	valid_0's l2: 883949
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [969]	valid_0's l2: 884212
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [970]	valid_0's l2: 884632
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [971]	valid_0's l2: 885676
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [972]	valid_0's l2: 883920
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [973]	valid_0's l2: 884819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [974]	valid_0's l2: 886066
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [975]	valid_0's l2: 885821
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [976]	valid_0's l2: 885816
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [977]	valid_0's l2: 885793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [978]	valid_0's l2: 885789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [979]	valid_0's l2: 885767
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [980]	valid_0's l2: 887500
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [981]	valid_0's l2: 889572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [982]	valid_0's l2: 890732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [983]	valid_0's l2: 891725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [984]	valid_0's l2: 893787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [985]	valid_0's l2: 891860
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [986]	valid_0's l2: 891909
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [987]	valid_0's l2: 892076
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [988]	valid_0's l2: 892134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [989]	valid_0's l2: 891954
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [990]	valid_0's l2: 892113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [991]	valid_0's l2: 894666
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [992]	valid_0's l2: 894765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [993]	valid_0's l2: 897294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [994]	valid_0's l2: 897403
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [995]	valid_0's l2: 897826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [996]	valid_0's l2: 897819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [997]	valid_0's l2: 897812
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [998]	valid_0's l2: 897806
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [999]	valid_0's l2: 897900
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	valid_0's l2: 897998
# 캠벨얼리

# %%
week1, week2, week4
# Out:
# ([1941.7436358116215,
#   5567.9570266300325,
#   1390.37463579598,
#   3125.1353876385338,
#   3659.766252843304],
#  [1802.1696922436597,
#   6519.95787606935,
#   1372.5260480517848,
#   3517.159675268186,
#   3260.7991760162254],
#  [1787.0364424847037,
#   4888.187307022983,
#   1282.0868866451985,
#   3513.5771846082125,
#   3086.8353733872677])

# %%
from pyrsistent import b


date = '20201106'

feature = [ '대파_가격(원/kg)', '깻잎_가격(원/kg)','팽이버섯_가격(원/kg)', '토마토_가격(원/kg)', '캠벨얼리_가격(원/kg)']
submission = submission.set_index('예측대상일자')
submission.loc[datetime.strptime(date, "%Y%m%d").strftime("%Y-%m-%d")+'+1week', feature] = week1
submission.loc[datetime.strptime(date, "%Y%m%d").strftime("%Y-%m-%d")+'+2week', feature] = week2
submission.loc[datetime.strptime(date, "%Y%m%d").strftime("%Y-%m-%d")+'+4week', feature] = week4
submission.reset_index(drop=False, inplace=True)
title = 'submissionLGBM' + date + '.csv'

# %%
submission.drop(columns=['배추_가격(원/kg)', '무_가격(원/kg)', '양파_가격(원/kg)', '건고추_가격(원/kg)',
       '마늘_가격(원/kg)',  '얼갈이배추_가격(원/kg)', '양배추_가격(원/kg)',
       '시금치_가격(원/kg)', '미나리_가격(원/kg)', '당근_가격(원/kg)', '파프리카_가격(원/kg)', '새송이_가격(원/kg)', 
       '청상추_가격(원/kg)', '백다다기_가격(원/kg)', '애호박_가격(원/kg)','샤인마스캇_가격(원/kg)'], inplace= True)

# %%
submission2 = submission[228:].round(2)
submission2
# Out:
#                예측대상일자  대파_가격(원/kg)  깻잎_가격(원/kg)  팽이버섯_가격(원/kg)  토마토_가격(원/kg)  \
# 228  2020-11-06+1week      1941.74      5567.96        1390.37       3125.14
# 229  2020-11-06+2week      1802.17      6519.96        1372.53       3517.16
# 230  2020-11-06+4week      1787.04      4888.19        1282.09       3513.58
#
#      캠벨얼리_가격(원/kg)
# 228        3659.77
# 229        3260.80
# 230        3086.84

# %%
# 실제값과 비교! 
private2 = private2[['date','요일','대파_가격(원/kg)', '깻잎_가격(원/kg)','팽이버섯_가격(원/kg)', '토마토_가격(원/kg)', '캠벨얼리_가격(원/kg)']]
private2_week = private2[::7]
private2_week[0:5]
# Out:
#          date   요일  대파_가격(원/kg)  깻잎_가격(원/kg)  팽이버섯_가격(원/kg)  토마토_가격(원/kg)  \
# 0  2020-11-06  금요일       2402.0       4831.0         1408.0        2806.0
# 7  2020-11-13  금요일       2374.0       5013.0         1532.0        2305.0
# 14 2020-11-20  금요일       2319.0       3316.0         1471.0        2015.0
# 21 2020-11-27  금요일       1841.0       3129.0         1294.0        1847.0
# 28 2020-12-04  금요일       1543.0       4326.0         1255.0        1814.0
#
#     캠벨얼리_가격(원/kg)
# 0          2797.0
# 7          3579.0
# 14         4859.0
# 21         4353.0
# 28         4063.0

# %%
submission2.to_csv(processed_path + title, encoding='utf-8-sig', index = False)
