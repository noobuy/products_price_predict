# %% [markdown]
# | EDA dataframe      | Description |due|
# | ----------- | ----------- |----------- |
# | grape_df  | 캠벨얼리 가격/거래량 + 소비자 물가 지수 + 자동차용경유 + 날씨(4개-평균기온, 평균온량, 일강수량, 일교차) + 수출입(4개) + 재배면적 + 샤인머스켓 거래량 + 실업률_경제활동인구(2개-경제활동인구, 실업률) + 최저시급    |20190101 ~ 20201104|
# | shinemuscat_df   |샤인마스캇  가격/거래량 + 소비자 물가 지수 + 자동차용경유 + 날씨(4개-평균기온, 평균온량, 일강수량, 일교차) + 수출입(4개) + 재배면적 + 블루베리 거래량 + 실업률_경제활동인구(2개-경제활동인구, 실업률) + 최저시급        |20190101 ~ 20201104|
# | df      | grape_train + shinemuscat_train       | 20190101 ~ 2020928|
#
#
# **train accuracy / test accuracy 의 차이 비교 overfitting = 20% 이상 (10~20%)**

# %% [markdown]
# https://dacon.io/competitions/official/235801/codeshare/4063?page=1&dtype=recent
#
# [lgbm 튜닝](https://dacon.io/competitions/official/235698/talkboard/404322)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic'

from numpy import array
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import matplotlib as mpl
from IPython.core.display import display, HTML
from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from statsmodels.tsa.seasonal import seasonal_decompose, STL
import urllib.request
import requests
import json
import datetime
import os
from datetime import datetime
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')
# Out:
# /var/folders/lm/z4n_2b8s6rj3_vv57sg789kc0000gn/T/ipykernel_58995/2031877544.py:10: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
# iMAC

raw_path = '/Users/cge/Documents/yeardream/project/kurly/products_price_predict/data/raw/'
processed_path = '/Users/cge/Documents/yeardream/project/kurly/products_price_predict/data/processed/'

# %%
# Macbook
    
# raw_path = '/Users/goeun/Documents/YearDream/ProJect/kurly_project/products_price_predict/data/raw/'
# processed_path = '/Users/goeun/Documents/YearDream/ProJect/kurly_project/products_price_predict/data/processed/'

# %%
grape = pd.read_csv(processed_path+'캠벨얼리_전처리후.csv')
mushroom = pd.read_csv(processed_path+'팽이버섯_전처리후.csv')

df = pd.merge(grape, mushroom, on=['date', '요일','계절'])

train = df[:1733]
test = df[1733:]
private = pd.read_csv(raw_path+'private_data.csv')
submission = pd.read_csv(raw_path+'sample_submission.csv')

print(grape.shape)
print(mushroom.shape)
print(df.shape)
print(private.shape)
print(submission.shape)
# Out:
# (1770, 9)
# (1770, 9)
# (1770, 15)
# (291, 44)
# (228, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1770 entries, 0 to 1769
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              1770 non-null   object
#  1   요일                1770 non-null   object
#  2   캠벨얼리_거래량(kg)      1770 non-null   float64
#  3   캠벨얼리_가격(원/kg)     1770 non-null   float64
#  4   캠벨얼리_거래량의_1주전_평균  1770 non-null   float64
#  5   캠벨얼리_가격의_1주전_평균   1770 non-null   float64
#  6   캠벨얼리_거래량의_2주전_평균  1770 non-null   float64
#  7   캠벨얼리_가격의_2주전_평균   1770 non-null   float64
#  8   계절                1770 non-null   int64
#  9   팽이버섯_거래량(kg)      1770 non-null   float64
#  10  팽이버섯_가격(원/kg)     1770 non-null   float64
#  11  팽이버섯_거래량의_1주전_평균  1770 non-null   float64
#  12  팽이버섯_가격의_1주전_평균   1770 non-null   float64
#  13  팽이버섯_거래량의_2주전_평균  1770 non-null   float64
#  14  팽이버섯_가격의_2주전_평균   1770 non-null   float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 221.2+ KB

# %% [markdown]
# # LGBM(LightGBM)

# %% [markdown]
# ## 캠벨얼리 & 팽이버섯
# 성능을 알아보기 위한 모델 <br> 캠벨얼리 가격을 예측
# [lightgbm](https://tpwkcorqhd.tistory.com/32)

# %%
private2 = private.copy()
private2 = private2[['date','캠벨얼리_거래량(kg)', '캠벨얼리_가격(원/kg)','팽이버섯_거래량(kg)', '팽이버섯_가격(원/kg)']]

# %%
private2['date'] = private2.date.astype(str).str.replace('-','')
private2['date'] = pd.to_datetime(private2.date, format='%Y%m%d')


t = ['월요일', '화요일', '수요일', '목요일', '금요일', '토요일', '일요일']
private2['요일'] = 0
temp = []
for i in range(len(private2)):
      temp.append(t[int(private2['date'][i].weekday())])
private2['요일'] = temp

private2 = private2[['date', '요일', '캠벨얼리_거래량(kg)', '캠벨얼리_가격(원/kg)','팽이버섯_거래량(kg)', '팽이버섯_가격(원/kg)']]

# %%
grape.columns
# Out:
# Index(['date', '요일', '캠벨얼리_거래량(kg)', '캠벨얼리_가격(원/kg)', '캠벨얼리_거래량의_1주전_평균',
#        '캠벨얼리_가격의_1주전_평균', '캠벨얼리_거래량의_2주전_평균', '캠벨얼리_가격의_2주전_평균', '계절'],
#       dtype='object')

# %%
class Nong1:
    

  def __init__(self, df, test):
    self.df = df
    self.test = test
    self.df = pd.concat([self.df, self.test], axis=0).reset_index(drop=True)
    self.df = self.df[1:].replace(0, np.NaN)
    self.df = self.df.interpolate().fillna(0)
    self.df.date = pd.to_datetime(self.df.date)
    self.df = pd.concat([self.df, pd.get_dummies(self.df['요일'])], axis=1)
    self.feature = self.df.columns[2:]
    self.df = self.df.reset_index(drop=True)

  def set_feature(self,name):
    self.name = name
    self.name1 = name+ "_가격(원/kg)"
    self.name2 = name+ "_거래량(kg)"
    self.name3 = name+ "_거래량의_1주전_평균"
    self.name4 = name+ '_가격의_1주전_평균'
    self.name5 = name+ '_거래량의_2주전_평균'
    self.name6 = name+ '_가격의_2주전_평균'
    self.name7 = '계절'
    self.feature = [self.name1, self.name2, self.name3, self.name4, self.name5, self.name6, self.name7, '금요일',   '목요일',   '수요일',   '월요일',   '일요일',   '토요일',   '화요일', 'resid']

  def set_target(self,week):
    if week == 1:
      self.df['target'] = self.df[self.name1].shift(-8)
    elif week == 2:
      self.df['target'] = self.df[self.name1].shift(-15)
    elif week == 4:
      self.df['target'] = self.df[self.name1].shift(-29)
    
    self.df['resid'] = 0
    stl = STL(self.df[['date', self.name1]].set_index('date'), period=12)
    res = stl.fit()
    self.df['resid'] = res.resid.values

  def set_model_lgb(self):
    import lightgbm as lgb
    self.scaler = RobustScaler()
    self.df[self.feature] = self.scaler.fit_transform(self.df[self.feature])
    self.df_learn = self.df[self.df['target'].notnull()]
    self.X = self.df_learn[self.feature]
    self.y = self.df_learn['target']
    
    self.train_split = 1733
    self.valid_split = 1770
    
    self.X_train = self.X[:self.train_split]
    self.y_train = self.y[:self.train_split]
    self.X_valid = self.X[self.train_split:self.valid_split]
    self.y_valid = self.y[self.train_split:self.valid_split]
    self.X_test = self.X[self.valid_split:]
    self.y_test = self.y[self.valid_split:]

    self.train_ds = lgb.Dataset(self.X_train,  label = self.y_train)
    self.valid_df = lgb.Dataset(self.X_valid,  label = self.y_valid)

#     self.params= {
#                 'num_leaves':10000 ,
#                 'objective' :'regression',
#                 'metric':'mse'
#                 } 
    self.params = {'learning_rate': 0.01, 
          'max_depth': 6, 
          'boosting': 'gbdt', 
          'objective': 'regression', 
          'metric': 'mse', 
          'is_training_metric': True, 
          'num_leaves': 100, 
          'feature_fraction': 0.8, 
          'bagging_fraction': 0.8, 
          'bagging_freq': 5, 
          'num_threads':8
             }
    self.num_round = 1000
    
    self.model_lgb = lgb.train(self.params, self.train_ds, self.num_round, self.valid_df)

  def get_plot_lgb(self):  
    self.y_pred = self.model_lgb.predict(self.X_test)
    self.RMSE = mean_squared_error(self.y_test, self.y_pred) ** 0.5

    plt.figure(figsize=(20, 10), dpi=300)
    plt.title(self.name + ' 가격 예측 결과'+   '   RMSE : ' + str(self.RMSE)[:7])
    plt.ylabel(self.name + ' 가격')
    plt.plot(np.array(self.y_train), alpha = 0.9, label = 'Real')
    plt.plot(self.model_lgb.predict(self.X_train), alpha = 0.6, linestyle = "--", label = 'Predict')
    plt.legend()
    plt.show()
    self.RMSE.round(2)

  def get_price_lgb(self):
    # self.X_test = X_test[self.feature]
    self.price = self.model_lgb.predict(self.X_test)
    return self.price[0]

# %%
my_nong1 = Nong1(df, private2)

my_nong1.set_feature('팽이버섯')

my_nong1.set_target(1)

# %%
my_nong1.set_model_lgb()
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000289 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1860
# [LightGBM] [Info] Number of data points in the train set: 1733, number of used features: 15
# [LightGBM] [Info] Start training from score 1697.105309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's l2: 57228.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's l2: 57610
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's l2: 57776.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's l2: 58112.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's l2: 58628.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's l2: 59206.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's l2: 59760.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's l2: 60335.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's l2: 61371
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 61718.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's l2: 62377.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's l2: 63343.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's l2: 64343
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's l2: 65203.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's l2: 66358.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's l2: 67216.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's l2: 68112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's l2: 68449.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's l2: 69288.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l2: 70024.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's l2: 71624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's l2: 72445
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's l2: 72994.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's l2: 73584.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's l2: 74163
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's l2: 74617.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's l2: 75047.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's l2: 75518
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's l2: 76172.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l2: 76818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's l2: 77906.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's l2: 78732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's l2: 79837.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's l2: 80956.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's l2: 82137.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's l2: 83022.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's l2: 83821.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's l2: 84997.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's l2: 85809.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l2: 86793.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's l2: 88245.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's l2: 89900.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's l2: 90622.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's l2: 91284.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's l2: 92134.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's l2: 93480.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's l2: 94534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's l2: 95020.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's l2: 96086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's l2: 96543.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's l2: 97425.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's l2: 98420.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's l2: 99307.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's l2: 100303
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's l2: 101397
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's l2: 102273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's l2: 103051
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's l2: 103903
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's l2: 104380
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's l2: 105294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's l2: 105826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	valid_0's l2: 107130
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's l2: 108098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's l2: 109585
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's l2: 110535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's l2: 111787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's l2: 111808
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's l2: 113004
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's l2: 114257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's l2: 115079
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's l2: 115887
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's l2: 117219
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's l2: 118962
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's l2: 119950
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's l2: 120928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's l2: 121798
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's l2: 122265
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's l2: 123136
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0's l2: 123458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's l2: 124757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [81]	valid_0's l2: 126104
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [82]	valid_0's l2: 127059
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	valid_0's l2: 127793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	valid_0's l2: 128933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	valid_0's l2: 130369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	valid_0's l2: 131925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	valid_0's l2: 133483
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	valid_0's l2: 134744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	valid_0's l2: 135824
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	valid_0's l2: 137192
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	valid_0's l2: 138245
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	valid_0's l2: 139336
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [93]	valid_0's l2: 140146
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	valid_0's l2: 141343
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	valid_0's l2: 142361
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	valid_0's l2: 142995
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	valid_0's l2: 143539
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	valid_0's l2: 144671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	valid_0's l2: 145528
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's l2: 146590
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	valid_0's l2: 147347
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	valid_0's l2: 148582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	valid_0's l2: 149290
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	valid_0's l2: 150018
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	valid_0's l2: 150963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	valid_0's l2: 151607
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	valid_0's l2: 152819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	valid_0's l2: 153646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	valid_0's l2: 154224
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	valid_0's l2: 155399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	valid_0's l2: 156553
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [112]	valid_0's l2: 157361
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	valid_0's l2: 158812
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [114]	valid_0's l2: 160050
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	valid_0's l2: 161449
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	valid_0's l2: 161999
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [117]	valid_0's l2: 162586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	valid_0's l2: 163486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	valid_0's l2: 164155
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	valid_0's l2: 165486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	valid_0's l2: 165791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	valid_0's l2: 166053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	valid_0's l2: 166987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	valid_0's l2: 167443
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's l2: 167720
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	valid_0's l2: 168278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [127]	valid_0's l2: 168867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [128]	valid_0's l2: 169336
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [129]	valid_0's l2: 169625
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	valid_0's l2: 170148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	valid_0's l2: 170663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	valid_0's l2: 171025
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	valid_0's l2: 171463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	valid_0's l2: 171968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [135]	valid_0's l2: 172329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's l2: 172640
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	valid_0's l2: 173228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	valid_0's l2: 173819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	valid_0's l2: 174137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	valid_0's l2: 174704
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	valid_0's l2: 175511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	valid_0's l2: 176072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	valid_0's l2: 176753
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	valid_0's l2: 176911
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	valid_0's l2: 177656
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	valid_0's l2: 178186
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [147]	valid_0's l2: 178600
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	valid_0's l2: 179131
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [149]	valid_0's l2: 179651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	valid_0's l2: 179687
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [151]	valid_0's l2: 180562
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [152]	valid_0's l2: 181383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	valid_0's l2: 182342
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	valid_0's l2: 183194
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	valid_0's l2: 184063
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	valid_0's l2: 185065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [157]	valid_0's l2: 185844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [158]	valid_0's l2: 186288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [159]	valid_0's l2: 187524
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	valid_0's l2: 187836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [161]	valid_0's l2: 187859
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [162]	valid_0's l2: 188966
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [163]	valid_0's l2: 190037
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [164]	valid_0's l2: 191256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	valid_0's l2: 191808
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [166]	valid_0's l2: 192137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	valid_0's l2:

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [905]	valid_0's l2: 289560
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [906]	valid_0's l2: 289900
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [907]	valid_0's l2: 290243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [908]	valid_0's l2: 290592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [909]	valid_0's l2: 290937
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [910]	valid_0's l2: 291279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [911]	valid_0's l2: 291134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [912]	valid_0's l2: 290902
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [913]	valid_0's l2: 290867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [914]	valid_0's l2: 290721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [915]	valid_0's l2: 290590
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [916]	valid_0's l2: 290615
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [917]	valid_0's l2: 290627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [918]	valid_0's l2: 290649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [919]	valid_0's l2: 290686
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [920]	valid_0's l2: 290698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [921]	valid_0's l2: 290897
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [922]	valid_0's l2: 290664
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [923]	valid_0's l2: 290877
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [924]	valid_0's l2: 291080
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [925]	valid_0's l2: 291243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [926]	valid_0's l2: 291375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [927]	valid_0's l2: 291506
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [928]	valid_0's l2: 291635
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [929]	valid_0's l2: 291760
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [930]	valid_0's l2: 291940
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [931]	valid_0's l2: 291890
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [932]	valid_0's l2: 292225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [933]	valid_0's l2: 292556
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [934]	valid_0's l2: 292894
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [935]	valid_0's l2: 293195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [936]	valid_0's l2: 293228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [937]	valid_0's l2: 293262
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [938]	valid_0's l2: 293295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [939]	valid_0's l2: 293328
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [940]	valid_0's l2: 293383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [941]	valid_0's l2: 293316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [942]	valid_0's l2: 293446
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [943]	valid_0's l2: 293785
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [944]	valid_0's l2: 293718
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [945]	valid_0's l2: 293641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [946]	valid_0's l2: 293964
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [947]	valid_0's l2: 294256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [948]	valid_0's l2: 294072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [949]	valid_0's l2: 294370
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	valid_0's l2: 294708
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [951]	valid_0's l2: 294711
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [952]	valid_0's l2: 295094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [953]	valid_0's l2: 295137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [954]	valid_0's l2: 295140
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [955]	valid_0's l2: 295143
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [956]	valid_0's l2: 295412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [957]	valid_0's l2: 295575
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [958]	valid_0's l2: 295724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [959]	valid_0's l2: 295532
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [960]	valid_0's l2: 295490
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [961]	valid_0's l2: 295651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [962]	valid_0's l2: 295659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [963]	valid_0's l2: 295667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [964]	valid_0's l2: 295637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [965]	valid_0's l2: 295844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [966]	valid_0's l2: 295861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [967]	valid_0's l2: 295879
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [968]	valid_0's l2: 295883
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [969]	valid_0's l2: 295715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [970]	valid_0's l2: 295734
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [971]	valid_0's l2: 295909
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [972]	valid_0's l2: 296138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [973]	valid_0's l2: 296304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [974]	valid_0's l2: 296268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [975]	valid_0's l2: 296495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [976]	valid_0's l2: 296455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [977]	valid_0's l2: 296475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [978]	valid_0's l2: 296509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [979]	valid_0's l2: 296570
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [980]	valid_0's l2: 296822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [981]	valid_0's l2: 296972
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [982]	valid_0's l2: 297012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [983]	valid_0's l2: 296990
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [984]	valid_0's l2: 297098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [985]	valid_0's l2: 297302
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [986]	valid_0's l2: 297218
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [987]	valid_0's l2: 297199
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [988]	valid_0's l2: 297178
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [989]	valid_0's l2: 297257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [990]	valid_0's l2: 297333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [991]	valid_0's l2: 297296
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [992]	valid_0's l2: 297231
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [993]	valid_0's l2: 297168
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [994]	valid_0's l2: 297110
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [995]	valid_0's l2: 297053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [996]	valid_0's l2: 296961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [997]	valid_0's l2: 296923
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [998]	valid_0's l2: 296781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [999]	valid_0's l2: 296689
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	valid_0's l2: 296611

# %%
my_nong1.get_plot_lgb()

# %% [markdown]
# ### 모델 실행

# %%
from sympy import Shi


weeks = [1, 2, 4]
features = ['캠벨얼리','팽이버섯'] # 팽이버섯

week1=[]
week2=[]
week4=[]

for week in weeks:
  print(week)
  for feature in features:
    my_nong1 = Nong1(df, private2)
    my_nong1.set_feature(feature)
    my_nong1.set_target(week)
    print(my_nong1.set_target(week))
    my_nong1.set_model_lgb()
    if week == 1:
      week1.append(my_nong1.get_price_lgb())
    if week == 2:
      week2.append(my_nong1.get_price_lgb())
    if week == 4:
      week4.append(my_nong1.get_price_lgb())
    print(feature)
# Out:
# 1
# None
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000425 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1856
# [LightGBM] [Info] Number of data points in the train set: 1733, number of used features: 15
# [LightGBM] [Info] Start training from score 3900.680479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's l2: 833381
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's l2: 837179
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's l2: 840948
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's l2: 844688
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's l2: 845757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's l2: 839907
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's l2: 840771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's l2: 841628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's l2: 835720
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 822599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's l2: 826306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's l2: 814617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's l2: 818132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's l2: 821408
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's l2: 810124
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's l2: 812785
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's l2: 815424
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's l2: 819785
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's l2: 815442
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l2: 814791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's l2: 821305
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's l2: 822455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's l2: 817436
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's l2: 807714
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's l2: 803127
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's l2: 797910
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's l2: 790176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's l2: 783978
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's l2: 779766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l2: 774664
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's l2: 771763
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's l2: 770528
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's l2: 771572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's l2: 768752
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's l2: 769784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's l2: 758950
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's l2: 762475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's l2: 765973
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's l2: 769445
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l2: 772319
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's l2: 768360
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's l2: 764928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's l2: 784769
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's l2: 804689
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's l2: 801365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's l2: 794386
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's l2: 789529
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's l2: 790043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's l2: 785327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's l2: 785827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's l2: 781539
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's l2: 783535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's l2: 780010
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's l2: 781965
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's l2: 778654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's l2: 772610
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's l2: 767939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's l2: 761760
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's l2: 761541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's l2: 755758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's l2: 756169
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	valid_0's l2: 748773
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's l2: 741172
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's l2: 733910
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's l2: 729644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's l2: 726916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's l2: 740817
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's l2: 736780
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's l2: 734053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's l2: 734340
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's l2: 729035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's l2: 723416
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's l2: 717879
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's l2: 712649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's l2: 707688
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's l2: 707600
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's l2: 707368
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's l2: 707188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0's l2: 703484
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's l2: 697649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [81]	valid_0's l2: 694525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [82]	valid_0's l2: 691443
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	valid_0's l2: 688144
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	valid_0's l2: 687769
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	valid_0's l2: 686626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	valid_0's l2: 684052
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	valid_0's l2: 682714
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	valid_0's l2: 680691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	valid_0's l2: 678237
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	valid_0's l2: 674882
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	valid_0's l2: 669347
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	valid_0's l2: 663895
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [93]	valid_0's l2: 665770
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	valid_0's l2: 665855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	valid_0's l2: 661965
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	valid_0's l2: 656076
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	valid_0's l2: 653626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	valid_0's l2: 648968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	valid_0's l2: 647861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's l2: 648124
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	valid_0's l2: 658032
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	valid_0's l2: 655421
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	valid_0's l2: 653982
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	valid_0's l2: 651427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	valid_0's l2: 649468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	valid_0's l2: 646082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	valid_0's l2: 643838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	valid_0's l2: 640501
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	valid_0's l2: 637270
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	valid_0's l2: 636457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	valid_0's l2: 633560
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [112]	valid_0's l2: 634372
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	valid_0's l2: 632289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [114]	valid_0's l2: 629591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	valid_0's l2: 627308
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	valid_0's l2: 636272
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [117]	valid_0's l2: 634842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	valid_0's l2: 632942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	valid_0's l2: 630791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	valid_0's l2: 639498
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	valid_0's l2: 635258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	valid_0's l2: 631149
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	valid_0's l2: 629149
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	valid_0's l2: 628615
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's l2: 624735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	valid_0's l2: 620534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [127]	valid_0's l2: 620467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [128]	valid_0's l2: 617888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [129]	valid_0's l2: 619926
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	valid_0's l2: 616574
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	valid_0's l2: 613933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	valid_0's l2: 613616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	valid_0's l2: 610223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	valid_0's l2: 609256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [135]	valid_0's l2: 606739
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's l2: 603221
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	valid_0's l2: 599755
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	valid_0's l2: 596341
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	valid_0's l2: 593936
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	valid_0's l2: 590591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	valid_0's l2: 586505
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	valid_0's l2: 584073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	valid_0's l2: 580065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	valid_0's l2: 580389
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	valid_0's l2: 577556
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	valid_0's l2: 575221
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [147]	valid_0's l2: 572920
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	valid_0's l2: 570651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [149]	valid_0's l2: 568413
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	valid_0's l2: 568390
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [151]	valid_0's l2: 564476
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [152]	valid_0's l2: 560886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	valid_0's l2: 557628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	valid_0's l2: 554198
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	valid_0's l2: 551431
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	valid_0's
5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [956]	valid_0's l2: 93380.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [957]	valid_0's l2: 93567.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [958]	valid_0's l2: 93684.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [959]	valid_0's l2: 93787.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [960]	valid_0's l2: 93818.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [961]	valid_0's l2: 93914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [962]	valid_0's l2: 93779.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [963]	valid_0's l2: 93873.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [964]	valid_0's l2: 93903.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [965]	valid_0's l2: 93979.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [966]	valid_0's l2: 93948.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [967]	valid_0's l2: 94027.1
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [968]	valid_0's l2: 94149.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [969]	valid_0's l2: 94228.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [970]	valid_0's l2: 94213.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [971]	valid_0's l2: 94349
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [972]	valid_0's l2: 94434.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [973]	valid_0's l2: 94462.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [974]	valid_0's l2: 94605.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [975]	valid_0's l2: 94689.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [976]	valid_0's l2: 94673.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [977]	valid_0's l2: 94664.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [978]	valid_0's l2: 94717.7
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [979]	valid_0's l2: 94578.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [980]	valid_0's l2: 94542.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [981]	valid_0's l2: 94474.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [982]	valid_0's l2: 94482.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [983]	valid_0's l2: 94489.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [984]	valid_0's l2: 94423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [985]	valid_0's l2: 94430.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [986]	valid_0's l2: 94428.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [987]	valid_0's l2: 94446.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [988]	valid_0's l2: 94522.3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [989]	valid_0's l2: 94570.4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [990]	valid_0's l2: 94605.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [991]	valid_0's l2: 94604.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [992]	valid_0's l2: 94548.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [993]	valid_0's l2: 94634.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [994]	valid_0's l2: 94658.8
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [995]	valid_0's l2: 94753.9
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [996]	valid_0's l2: 94865.5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [997]	valid_0's l2: 94889.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [998]	valid_0's l2: 94928.2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [999]	valid_0's l2: 94948.6
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	valid_0's l2: 94990.7
# 팽이버섯

# %%
week1, week2, week4
# Out:
# ([3659.766252843304, 1390.37463579598],
#  [3260.7991760162254, 1372.5260480517848],
#  [3086.8353733872677, 1282.0868866451985])

# %%
from pyrsistent import b


date = '20201106'

feature = [ '캠벨얼리_가격(원/kg)','팽이버섯_가격(원/kg)']
submission = submission.set_index('예측대상일자')
submission.loc[datetime.strptime(date, "%Y%m%d").strftime("%Y-%m-%d")+'+1week', feature] = week1
submission.loc[datetime.strptime(date, "%Y%m%d").strftime("%Y-%m-%d")+'+2week', feature] = week2
submission.loc[datetime.strptime(date, "%Y%m%d").strftime("%Y-%m-%d")+'+4week', feature] = week4
submission.reset_index(drop=False, inplace=True)
title = 'submission' + date + '.csv'

# %%
submission.drop(columns=['배추_가격(원/kg)', '무_가격(원/kg)', '양파_가격(원/kg)', '건고추_가격(원/kg)',
       '마늘_가격(원/kg)', '대파_가격(원/kg)', '얼갈이배추_가격(원/kg)', '양배추_가격(원/kg)',
       '깻잎_가격(원/kg)', '시금치_가격(원/kg)', '미나리_가격(원/kg)', '당근_가격(원/kg)',
       '파프리카_가격(원/kg)', '새송이_가격(원/kg)', '토마토_가격(원/kg)',
       '청상추_가격(원/kg)', '백다다기_가격(원/kg)', '애호박_가격(원/kg)','샤인마스캇_가격(원/kg)'], inplace= True)

# %%
submission2 = submission[228:]
submission2
# Out:
#                예측대상일자  팽이버섯_가격(원/kg)  캠벨얼리_가격(원/kg)
# 228  2020-11-06+1week    1390.374636    3659.766253
# 229  2020-11-06+2week    1372.526048    3260.799176
# 230  2020-11-06+4week    1282.086887    3086.835373

# %%
# 실제값과 비교! 
private2 = private2[['date','요일','팽이버섯_가격(원/kg)','캠벨얼리_가격(원/kg)',]]
private2_week = private2[::7]
private2_week[:5]
# Out:
#          date   요일  팽이버섯_가격(원/kg)  캠벨얼리_가격(원/kg)
# 0  2020-11-06  금요일         1408.0         2797.0
# 7  2020-11-13  금요일         1532.0         3579.0
# 14 2020-11-20  금요일         1471.0         4859.0
# 21 2020-11-27  금요일         1294.0         4353.0
# 28 2020-12-04  금요일         1255.0         4063.0

# %%
submission2.to_csv(processed_path + title, encoding='utf-8-sig', index = False)
